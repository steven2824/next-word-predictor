# %%
from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM
import torch

# Load model
print("Loading AI model...")
model_name = "distilgpt2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)
# Out:
# Loading AI model...

# %%
# Simple example
text = "The weather today is "
print(f"\nStarting text: '{text}'")
print("\nGenerating word by word...\n")

# Generate 5 words, one at a time
current_text = text
for step in range(5):
    print(f"--- Step {step + 1} ---")
    print(f"Current: '{current_text}'")
    
    # Encode current text
    input_ids = tokenizer.encode(current_text, return_tensors="pt")
    
    # Get predictions
    with torch.no_grad():
        outputs = model(input_ids)
        predictions = outputs.logits
    
    # Get the predictions for the NEXT token
    next_token_logits = predictions[0, -1, :]
    next_token_probs = torch.softmax(next_token_logits, dim=0)
    
    # Get top 5 predictions
    top_probs, top_indices = torch.topk(next_token_probs, 5)
    
    print("Top 5 next word predictions:")
    for i, (prob, idx) in enumerate(zip(top_probs, top_indices)):
        word = tokenizer.decode([idx])
        print(f"  {i+1}. '{word}' ({prob.item()*100:.1f}% confident)")
    
    # Use the most likely word
    next_token_id = top_indices[0]
    next_word = tokenizer.decode([next_token_id])
    current_text += next_word
    
    print(f"✓ Chosen: '{next_word}'")
    print(f"New text: '{current_text}'\n")

print(f"\nFinal generated text: '{current_text}'")
# Out:
# Starting text: 'The weather today is '
#
# Generating word by word...
#
# --- Step 1 ---
# Current: 'The weather today is '
# Top 5 next word predictions:
#   1. 'iced' (45.6% confident)
#   2. ' ' (18.6% confident)
#   3. '!!!' (2.5% confident)
#   4. '�' (2.0% confident)
#   5. '????' (1.8% confident)
# ✓ Chosen: 'iced'
# New text: 'The weather today is iced'
#
# --- Step 2 ---
# Current: 'The weather today is iced'
# Top 5 next word predictions:
#   1. ' up' (13.1% confident)
#   2. ' with' (11.3% confident)
#   3. ' and' (8.4% confident)
#   4. '.' (8.0% confident)
#   5. ',' (8.0% confident)
# ✓ Chosen: ' up'
# New text: 'The weather today is iced up'
#
# --- Step 3 ---
# Current: 'The weather today is iced up'
# Top 5 next word predictions:
#   1. ',' (15.7% confident)
#   2. ' and' (14.9% confident)
#   3. '.' (10.3% confident)
#   4. ' by' (6.9% confident)
#   5. ' to' (4.9% confident)
# ✓ Chosen: ','
# New text: 'The weather today is iced up,'
#
# --- Step 4 ---
# Current: 'The weather today is iced up,'
# Top 5 next word predictions:
#   1. ' and' (17.8% confident)
#   2. '�' (14.9% confident)
#   3. ' but' (11.5% confident)
#   4. ' so' (10.3% confident)
#   5. ' it' (3.0% confident)
# ✓ Chosen: ' and'
# New text: 'The weather today is iced up, and'
#
# --- Step 5 ---
# Current: 'The weather today is iced up, and'
# Top 5 next word predictions:
#   1. ' the' (12.7% confident)
#   2. ' I' (9.4% confident)
#   3. ' it' (9.0% confident)
#   4. ' we' (7.7% confident)
#   5. ' you' (2.5% confident)
# ✓ Chosen: ' the'
# New text: 'The weather today is iced up, and the'
#
# --- Step 6 ---
# Current: 'The weather today is iced up, and the'
# Top 5 next word predictions:
#   1. ' weather' (7.6% confident)
#   2. ' sun' (4.3% confident)
#   3. ' temperature' (2.7% confident)
#   4. ' wind' (1.9% confident)
#   5. ' rain' (1.5% confident)
# ✓ Chosen: ' weather'
# New text: 'The weather today is iced up, and the weather'
#
# --- Step 7 ---
# Current: 'The weather today is iced up, and the weather'
# Top 5 next word predictions:
#   1. ' is' (49.2% confident)
#   2. ' will' (10.4% confident)
#   3. ' has' (5.6% confident)
#   4. ' in' (1.5% confident)
#   5. ' was' (1.4% confident)
# ✓ Chosen: ' is'
# New text: 'The weather today is iced up, and the weather is'
#
# --- Step 8 ---
# Current: 'The weather today is iced up, and the weather is'
# Top 5 next word predictions:
#   1. ' getting' (4.2% confident)
#   2. ' not' (2.9% confident)
#   3. ' ' (2.9% confident)
#   4. ' going' (2.8% confident)
#   5. ' still' (2.5% confident)
# ✓ Chosen: ' getting'
# New text: 'The weather today is iced up, and the weather is getting'
#
# --- Step 9 ---
# Current: 'The weather today is iced up, and the weather is getting'
# Top 5 next word predictions:
#   1. ' better' (21.1% confident)
#   2. ' warmer' (8.0% confident)
#   3. ' a' (6.4% confident)
#   4. ' colder' (6.1% confident)
#   5. ' worse' (5.1% confident)
# ✓ Chosen: ' better'
# New text: 'The weather today is iced up, and the weather is getting better'
#
# --- Step 10 ---
# Current: 'The weather today is iced up, and the weather is getting better'
# Top 5 next word predictions:
#   1. '.' (35.2% confident)
#   2. ' and' (14.5% confident)
#   3. ',' (10.8% confident)
#   4. '."' (6.7% confident)
#   5. ',"' (2.5% confident)
# ✓ Chosen: '.'
# New text: 'The weather today is iced up, and the weather is getting better.'
#
# --- Step 11 ---
# Current: 'The weather today is iced up, and the weather is getting better.'
# Top 5 next word predictions:
#   1. '�' (20.4% confident)
#   2. '
# ' (11.7% confident)
#   3. ' I' (5.6% confident)
#   4. ' The' (5.1% confident)
#   5. ' It' (3.4% confident)
# ✓ Chosen: '�'
# New text: 'The weather today is iced up, and the weather is getting better.�'
#
# --- Step 12 ---
# Current: 'The weather today is iced up, and the weather is getting better.�'
# Top 5 next word predictions:
#   1. '
# ' (38.0% confident)
#   2. '<|endoftext|>' (26.1% confident)
#   3. ' The' (2.4% confident)
#   4. ' It' (1.1% confident)
#   5. '
#
# ' (0.9% confident)
# ✓ Chosen: '
# '
# New text: 'The weather today is iced up, and the weather is getting better.�
# '
#
# --- Step 13 ---
# Current: 'The weather today is iced up, and the weather is getting better.�
# '
# Top 5 next word predictions:
#   1. '
# ' (94.8% confident)
#   2. 'The' (2.0% confident)
#   3. 'A' (0.2% confident)
#   4. '�' (0.2% confident)
#   5. '"' (0.1% confident)
# ✓ Chosen: '
# '
# New text: 'The weather today is iced up, and the weather is getting better.�
#
# '
#
# --- Step 14 ---
# Current: 'The weather today is iced up, and the weather is getting better.�
#
# '
# Top 5 next word predictions:
#   1. '
# ' (97.2% confident)
#   2. 'The' (0.8% confident)
#   3. '<|endoftext|>' (0.2% confident)
#   4. 'I' (0.1% confident)
#   5. 'A' (0.1% confident)
# ✓ Chosen: '
# '
# New text: 'The weather today is iced up, and the weather is getting better.�
#
#
# '
#
# --- Step 15 ---
# Current: 'The weather today is iced up, and the weather is getting better.�
#
#
# '
# Top 5 next word predictions:
#   1. '
# ' (76.9% confident)
#   2. 'The' (5.4% confident)
#   3. 'A' (0.9% confident)
#   4. 'This' (0.7% confident)
#   5. 'I' (0.6% confident)
# ✓ Chosen: '
# '
# New text: 'The weather today is iced up, and the weather is getting better.�
#
#
#
# '
#
# --- Step 16 ---
# Current: 'The weather today is iced up, and the weather is getting better.�
#
#
#
# '
# Top 5 next word predictions:
#   1. '
# ' (93.0% confident)
#   2. 'The' (1.4% confident)
#   3. 'I' (0.5% confident)
#   4. '<|endoftext|>' (0.4% confident)
#   5. 'A' (0.3% confident)
# ✓ Chosen: '
# '
# New text: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
# '
#
# --- Step 17 ---
# Current: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
# '
# Top 5 next word predictions:
#   1. '
# ' (43.3% confident)
#   2. 'The' (7.7% confident)
#   3. 'I' (1.8% confident)
#   4. 'This' (1.8% confident)
#   5. 'A' (1.7% confident)
# ✓ Chosen: '
# '
# New text: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
# '
#
# --- Step 18 ---
# Current: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
# '
# Top 5 next word predictions:
#   1. '
# ' (77.9% confident)
#   2. 'The' (2.5% confident)
#   3. 'I' (1.9% confident)
#   4. '<|endoftext|>' (1.0% confident)
#   5. 'A' (0.9% confident)
# ✓ Chosen: '
# '
# New text: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
#
# '
#
# --- Step 19 ---
# Current: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
#
# '
# Top 5 next word predictions:
#   1. '
# ' (25.3% confident)
#   2. 'The' (7.2% confident)
#   3. 'I' (2.7% confident)
#   4. 'This' (2.2% confident)
#   5. 'A' (1.7% confident)
# ✓ Chosen: '
# '
# New text: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
#
#
# '
#
# --- Step 20 ---
# Current: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
#
#
# '
# Top 5 next word predictions:
#   1. '
# ' (59.0% confident)
#   2. 'I' (3.0% confident)
#   3. 'The' (2.9% confident)
#   4. '<|endoftext|>' (2.0% confident)
#   5. 'A' (1.1% confident)
# ✓ Chosen: '
# '
# New text: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
#
#
#
# '
#
# --- Step 21 ---
# Current: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
#
#
#
# '
# Top 5 next word predictions:
#   1. '
# ' (19.0% confident)
#   2. 'The' (6.5% confident)
#   3. 'I' (3.3% confident)
#   4. 'This' (2.3% confident)
#   5. 'A' (1.6% confident)
# ✓ Chosen: '
# '
# New text: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
#
#
#
#
# '
#
# --- Step 22 ---
# Current: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
#
#
#
#
# '
# Top 5 next word predictions:
#   1. '
# ' (45.6% confident)
#   2. '<|endoftext|>' (3.4% confident)
#   3. 'I' (3.3% confident)
#   4. 'The' (3.0% confident)
#   5. 'This' (1.3% confident)
# ✓ Chosen: '
# '
# New text: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
#
#
#
#
#
# '
#
# --- Step 23 ---
# Current: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
#
#
#
#
#
# '
# Top 5 next word predictions:
#   1. '
# ' (17.4% confident)
#   2. 'The' (6.2% confident)
#   3. 'I' (3.7% confident)
#   4. 'This' (2.3% confident)
#   5. 'We' (1.6% confident)
# ✓ Chosen: '
# '
# New text: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
#
#
#
#
#
#
# '
#
# --- Step 24 ---
# Current: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
#
#
#
#
#
#
# '
# Top 5 next word predictions:
#   1. '
# ' (41.2% confident)
#   2. '<|endoftext|>' (5.0% confident)
#   3. 'I' (3.2% confident)
#   4. 'The' (3.1% confident)
#   5. 'This' (1.3% confident)
# ✓ Chosen: '
# '
# New text: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
#
#
#
#
#
#
#
# '
#
# --- Step 25 ---
# Current: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
#
#
#
#
#
#
#
# '
# Top 5 next word predictions:
#   1. '
# ' (17.4% confident)
#   2. 'The' (6.1% confident)
#   3. 'I' (3.8% confident)
#   4. 'This' (2.3% confident)
#   5. 'We' (1.6% confident)
# ✓ Chosen: '
# '
# New text: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
#
#
#
#
#
#
#
#
# '
#
# --- Step 26 ---
# Current: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
#
#
#
#
#
#
#
#
# '
# Top 5 next word predictions:
#   1. '
# ' (41.5% confident)
#   2. '<|endoftext|>' (7.0% confident)
#   3. 'The' (3.1% confident)
#   4. 'I' (2.9% confident)
#   5. 'We' (1.2% confident)
# ✓ Chosen: '
# '
# New text: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# '
#
# --- Step 27 ---
# Current: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# '
# Top 5 next word predictions:
#   1. '
# ' (17.9% confident)
#   2. 'The' (6.1% confident)
#   3. 'I' (3.9% confident)
#   4. 'This' (2.3% confident)
#   5. 'We' (1.6% confident)
# ✓ Chosen: '
# '
# New text: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# '
#
# --- Step 28 ---
# Current: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# '
# Top 5 next word predictions:
#   1. '
# ' (42.2% confident)
#   2. '<|endoftext|>' (8.5% confident)
#   3. 'The' (3.2% confident)
#   4. 'I' (2.6% confident)
#   5. '
#
# ' (1.3% confident)
# ✓ Chosen: '
# '
# New text: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# '
#
# --- Step 29 ---
# Current: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# '
# Top 5 next word predictions:
#   1. '
# ' (18.9% confident)
#   2. 'The' (6.1% confident)
#   3. 'I' (3.9% confident)
#   4. 'This' (2.2% confident)
#   5. 'We' (1.7% confident)
# ✓ Chosen: '
# '
# New text: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# '
#
# --- Step 30 ---
# Current: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# '
# Top 5 next word predictions:
#   1. '
# ' (43.9% confident)
#   2. '<|endoftext|>' (9.5% confident)
#   3. 'The' (3.1% confident)
#   4. 'I' (2.4% confident)
#   5. '
#
# ' (1.7% confident)
# ✓ Chosen: '
# '
# New text: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# '
#
#
# Final generated text: 'The weather today is iced up, and the weather is getting better.�
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# '
